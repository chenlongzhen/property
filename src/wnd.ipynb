# %%
"""Example code for TensorFlow Wide & Deep Tutorial using TF.Learn API."""
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import sys
import tempfile

import pandas as pd
from six.moves import urllib
import tensorflow as tf

# %%
#data processing

train_df = pd.read_csv("../data/train_df.csv",index_col=0)
train_df.shape
# Out:
# (90275, 61)

# %%
train_df.head()
# Out:
#    parcelid  logerror  airconditioningtypeid  architecturalstyletypeid  \
# 0  11016594    0.0276                    1.0                       NaN
# 1  14366692   -0.1684                    NaN                       NaN
# 2  12098116   -0.0040                    1.0                       NaN
# 3  12643413    0.0218                    1.0                       NaN
# 4  14432541   -0.0050                    NaN                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          2.0         3.0                  NaN
# 1           NaN          3.5         4.0                  NaN
# 2           NaN          3.0         2.0                  NaN
# 3           NaN          2.0         2.0                  NaN
# 4           NaN          2.5         4.0                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr        ...         \
# 0                    4.0                2.0        ...
# 1                    NaN                3.5        ...
# 2                    4.0                3.0        ...
# 3                    4.0                2.0        ...
# 4                    NaN                2.5        ...
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    122754.0           360170.0          2015.0
# 1                    346458.0           585529.0          2015.0
# 2                     61994.0           119906.0          2015.0
# 3                    171518.0           244880.0          2015.0
# 4                    169574.0           434551.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               237416.0    6735.88                 NaN                 NaN
# 1               239071.0   10153.02                 NaN                 NaN
# 2                57912.0   11484.48                 NaN                 NaN
# 3                73362.0    3048.74                 NaN                 NaN
# 4               264977.0    5488.96                 NaN                 NaN
#
#    censustractandblock  transaction_month  transaction_year
# 0         6.037107e+13                  1              2016
# 1                  NaN                  1              2016
# 2         6.037464e+13                  1              2016
# 3         6.037296e+13                  1              2016
# 4         6.059042e+13                  1              2016
#
# [5 rows x 61 columns]

# %%
pd.options.display.max_rows = 65

dtype_df = train_df.dtypes.reset_index()
dtype_df.columns = ["Count", "Column Type"]
d_object = dtype_df.ix[dtype_df["Column Type"] != "object"]
dtype_df
# Out:
#                            Count Column Type
# 0                       parcelid       int64
# 1                       logerror     float64
# 2          airconditioningtypeid     float64
# 3       architecturalstyletypeid     float64
# 4                   basementsqft     float64
# 5                    bathroomcnt     float64
# 6                     bedroomcnt     float64
# 7            buildingclasstypeid     float64
# 8          buildingqualitytypeid     float64
# 9              calculatedbathnbr     float64
# 10                    decktypeid     float64
# 11      finishedfloor1squarefeet     float64
# 12  calculatedfinishedsquarefeet     float64
# 13          finishedsquarefeet12     float64
# 14          finishedsquarefeet13     float64
# 15          finishedsquarefeet15     float64
# 16          finishedsquarefeet50     float64
# 17           finishedsquarefeet6     float64
# 18                          fips     float64
# 19                  fireplacecnt     float64
# 20                   fullbathcnt     float64
# 21                  garagecarcnt     float64
# 22               garagetotalsqft     float64
# 23                hashottuborspa      object
# 24         heatingorsystemtypeid     float64
# 25                      latitude     float64
# 26                     longitude     float64
# 27             lotsizesquarefeet     float64
# 28                       poolcnt     float64
# 29                   poolsizesum     float64
# 30                  pooltypeid10     float64
# 31                   pooltypeid2     float64
# 32                   pooltypeid7     float64
# 33     propertycountylandusecode      object
# 34         propertylandusetypeid     float64
# 35            propertyzoningdesc      object
# 36        rawcensustractandblock     float64
# 37                  regionidcity     float64
# 38                regionidcounty     float64
# 39          regionidneighborhood     float64
# 40                   regionidzip     float64
# 41                       roomcnt     float64
# 42                   storytypeid     float64
# 43           threequarterbathnbr     float64
# 44        typeconstructiontypeid     float64
# 45                       unitcnt     float64
# 46            yardbuildingsqft17     float64
# 47            yardbuildingsqft26     float64
# 48                     yearbuilt     float64
# 49               numberofstories     float64
# 50                 fireplaceflag      object
# 51    structuretaxvaluedollarcnt     float64
# 52             taxvaluedollarcnt     float64
# 53                assessmentyear     float64
# 54         landtaxvaluedollarcnt     float64
# 55                     taxamount     float64
# 56            taxdelinquencyflag      object
# 57            taxdelinquencyyear     float64
# 58           censustractandblock     float64
# 59             transaction_month       int64
# 60              transaction_year       int64

# %%
# default-dic
default_dic = {}
for ind,row in dtype_df.iterrows():
    if row['Column Type'] == 'float64':
        default_dic[row['Count']] = -1
    else:
        default_dic[row['Count']] = 'missing'
#default_dic     
train_df.fillna(value = default_dic, inplace=True)

# %%
import numpy as np
wide_columns = []
deep_columns = []

hashottuborspa = tf.feature_column.categorical_column_with_hash_bucket(
    "hashottuborspa",2)

propertycountylandusecode = tf.feature_column.categorical_column_with_hash_bucket(
    "propertycountylandusecode",80)

propertyzoningdesc = tf.feature_column.categorical_column_with_hash_bucket(
    "propertyzoningdesc",2000)

fireplaceflag = tf.feature_column.categorical_column_with_hash_bucket(
    "fireplaceflag",2)

taxdelinquencyflag = tf.feature_column.categorical_column_with_hash_bucket(
    "taxdelinquencyflag",2)

hashottuborspa = tf.feature_column.indicator_column(hashottuborspa)
propertycountylandusecode = tf.feature_column.indicator_column(propertycountylandusecode)
propertyzoningdesc = tf.feature_column.indicator_column(propertyzoningdesc)
fireplaceflag = tf.feature_column.indicator_column(fireplaceflag)
taxdelinquencyflag = tf.feature_column.indicator_column(taxdelinquencyflag)

deep_columns=[hashottuborspa,propertycountylandusecode,
              propertyzoningdesc,fireplaceflag,taxdelinquencyflag]

# float and int

## parcelid
d_object = dtype_df.ix[dtype_df["Column Type"] != "object"]
d_object = d_object.ix[d_object.Count != 'parcelid']
parcelid =  tf.contrib.layers.sparse_column_with_integerized_feature(
    'parcelid', bucket_size=100000)
parcelid = tf.feature_column.embedding_column(parcelid,32) # embedding

deep_columns.append(parcelid)
wide_columns.append(parcelid)

## 
for col in d_object['Count'].values:
    
    category = train_df[col].value_counts().shape[0]
    if category < 1000:
        print("feature:{}, category: {} < 1000, hashing.".format(col,category))
       
        train_df[col] = train_df[col].astype(np.int32)
        
        layer = tf.contrib.layers.sparse_column_with_integerized_feature(
    col, bucket_size=category)
        wide_columns.append(layer)
        
        # embeding
        layer = tf.contrib.layers.embedding_column(
            layer, dimension=32, combiner="mean")
        deep_columns.append(layer)
        
    else:
        print("feature:{} ,category: {} > 1000, numneric.".format(col,category))
        layer = tf.feature_column.numeric_column(col)
        
        deep_columns.append(layer)
        
train_df.to_csv("../data/train_df_new.csv")
# Out:
# feature:logerror, category: 873 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:airconditioningtypeid, category: 7 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:architecturalstyletypeid, category: 7 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:basementsqft, category: 40 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:bathroomcnt, category: 23 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:bedroomcnt, category: 8 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:buildingclasstypeid, category: 2 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:buildingqualitytypeid, category: 9 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:calculatedbathnbr, category: 23 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:decktypeid, category: 2 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:finishedfloor1squarefeet ,category: 1887 > 1000, numneric.
# feature:calculatedfinishedsquarefeet ,category: 5103 > 1000, numneric.
# feature:finishedsquarefeet12 ,category: 4983 > 1000, numneric.
# feature:finishedsquarefeet13, category: 12 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:finishedsquarefeet15 ,category: 1916 > 1000, numneric.
# feature:finishedsquarefeet50 ,category: 1899 > 1000, numneric.
# feature:finishedsquarefeet6, category: 361 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:fips, category: 3 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:fireplacecnt, category: 6 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:fullbathcnt, category: 15 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:garagecarcnt, category: 16 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:garagetotalsqft, category: 871 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:heatingorsystemtypeid, category: 13 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:latitude ,category: 73312 > 1000, numneric.
# feature:longitude ,category: 71900 > 1000, numneric.
# feature:lotsizesquarefeet ,category: 20017 > 1000, numneric.
# feature:poolcnt, category: 2 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:poolsizesum, category: 274 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:pooltypeid10, category: 2 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:pooltypeid2, category: 2 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:pooltypeid7, category: 2 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:propertylandusetypeid, category: 14 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:rawcensustractandblock ,category: 8357 > 1000, numneric.
# feature:regionidcity, category: 178 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:regionidcounty, category: 3 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:regionidneighborhood, category: 495 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:regionidzip, category: 389 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:roomcnt, category: 17 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:storytypeid, category: 2 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:threequarterbathnbr, category: 5 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:typeconstructiontypeid, category: 4 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:unitcnt, category: 11 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:yardbuildingsqft17, category: 568 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:yardbuildingsqft26, category: 74 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:yearbuilt, category: 131 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:numberofstories, category: 5 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:structuretaxvaluedollarcnt ,category: 55451 > 1000, numneric.
# feature:taxvaluedollarcnt ,category: 55939 > 1000, numneric.
# feature:assessmentyear, category: 1 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:landtaxvaluedollarcnt ,category: 57067 > 1000, numneric.
# feature:taxamount ,category: 85111 > 1000, numneric.
# feature:taxdelinquencyyear, category: 12 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:censustractandblock ,category: 8335 > 1000, numneric.
# feature:transaction_month, category: 12 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.
# feature:transaction_year, category: 1 < 1000, hashing.
# WARNING:tensorflow:The default stddev value of initializer will change from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" after 2017/02/25.

# %%
def build_estimator(model_dir, model_type):
    """Build an estimator."""
    if model_type == "wide":
        m = tf.estimator.LinearRegressor(
        model_dir=model_dir, feature_columns=wide_columns)
    elif model_type == "deep":
        m = tf.estimator.DNNRegressor(
        model_dir=model_dir,
        feature_columns=deep_columns,
        hidden_units=[100, 50])
    else:
        m = tf.estimator.DNNLinearCombinedRegressor(
        model_dir=model_dir,
        linear_feature_columns=wide_columns,
        dnn_feature_columns=deep_columns,
        dnn_hidden_units=[100, 50])
    return m


def input_fn(data_file, num_epochs, shuffle):
    """Input builder function."""
    df_data = pd.read_csv(data_file,engine="python",index_col=0)
    
    labels = train_df['logerror']
    return tf.estimator.inputs.pandas_input_fn(
      x=df_data,
      y=labels,
      batch_size=100,
      num_epochs=num_epochs,
      shuffle=shuffle,
      num_threads=5)


def train_and_eval(model_dir, model_type, train_steps, train_data, test_data):
    """Train and evaluate the model."""

    m = build_estimator(model_dir, model_type)
  # set num_epochs to None to get infinite stream of data.
    m.train(
      input_fn=input_fn(train_data, num_epochs=None, shuffle=True),
      steps=train_steps)
  # set steps to None to run evaluation until all data consumed.
    results = m.evaluate(
      input_fn=input_fn(test_data, num_epochs=1, shuffle=False),
      steps=None)
    print("model directory = %s" % model_dir)
    for key in sorted(results):
        print("%s: %s" % (key, results[key]))


FLAGS = None


def main(_):
    train_and_eval("/data/chenlongzhen/property/data/modedir", "wide_n_deep", 50,
                 "/data/chenlongzhen/property/data/train_df_new.csv", "/data/chenlongzhen/property/data/train_df_new.csv")


if __name__ == "__main__":
    main(1)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_model_dir': '/data/chenlongzhen/property/data/modedir', '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-0142d0ec609b> in <module>()
#      58
#      59 if __name__ == "__main__":
# ---> 60     main(1)
#
# <ipython-input-72-0142d0ec609b> in main(_)
#      54 def main(_):
#      55     train_and_eval("/data/chenlongzhen/property/data/modedir", "wide_n_deep", 50,
# ---> 56                  "/data/chenlongzhen/property/data/train_df_new.csv", "/data/chenlongzhen/property/data/train_df_new.csv")
#      57
#      58
#
# <ipython-input-72-0142d0ec609b> in train_and_eval(model_dir, model_type, train_steps, train_data, test_data)
#      39     m.train(
#      40       input_fn=input_fn(train_data, num_epochs=None, shuffle=True),
# ---> 41       steps=train_steps)
#      42   # set steps to None to run evaluation until all data consumed.
#      43     results = m.evaluate(
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/estimator/estimator.pyc in train(self, input_fn, hooks, steps, max_steps)
#     239       hooks.append(training.StopAtStepHook(steps, max_steps))
#     240
# --> 241     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#     242     logging.info('Loss for final step: %s.', loss)
#     243     return self
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/estimator/estimator.pyc in _train_model(self, input_fn, hooks)
#     681           save_summaries_steps=self._config.save_summary_steps,
#     682           config=self._session_config,
# --> 683           log_step_count_steps=self._config.log_step_count_steps) as mon_sess:
#     684         loss = None
#     685         while not mon_sess.should_stop():
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in MonitoredTrainingSession(master, is_chief, checkpoint_dir, scaffold, hooks, chief_only_hooks, save_checkpoint_secs, save_summaries_steps, save_summaries_secs, config, stop_grace_period_secs, log_step_count_steps)
#     363     all_hooks.extend(hooks)
#     364   return MonitoredSession(session_creator=session_creator, hooks=all_hooks,
# --> 365                           stop_grace_period_secs=stop_grace_period_secs)
#     366
#     367
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in __init__(self, session_creator, hooks, stop_grace_period_secs)
#     666     super(MonitoredSession, self).__init__(
#     667         session_creator, hooks, should_recover=True,
# --> 668         stop_grace_period_secs=stop_grace_period_secs)
#     669
#     670
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in __init__(self, session_creator, hooks, should_recover, stop_grace_period_secs)
#     488         stop_grace_period_secs=stop_grace_period_secs)
#     489     if should_recover:
# --> 490       self._sess = _RecoverableSession(self._coordinated_creator)
#     491     else:
#     492       self._sess = self._coordinated_creator.create_session()
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in __init__(self, sess_creator)
#     840     """
#     841     self._sess_creator = sess_creator
# --> 842     _WrappedSession.__init__(self, self._create_session())
#     843
#     844   def _create_session(self):
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in _create_session(self)
#     845     while True:
#     846       try:
# --> 847         return self._sess_creator.create_session()
#     848       except _PREEMPTION_ERRORS as e:
#     849         logging.info('An error was raised while a session was being created. '
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in create_session(self)
#     549       """Creates a coordinated session."""
#     550       # Keep the tf_sess for unit testing.
# --> 551       self.tf_sess = self._session_creator.create_session()
#     552       # We don't want coordinator to suppress any exception.
#     553       self.coord = coordinator.Coordinator(clean_stop_exception_types=[])
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in create_session(self)
#     423         init_op=self._scaffold.init_op,
#     424         init_feed_dict=self._scaffold.init_feed_dict,
# --> 425         init_fn=self._scaffold.init_fn)
#     426
#     427
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/session_manager.pyc in prepare_session(self, master, init_op, saver, checkpoint_dir, checkpoint_filename_with_path, wait_for_checkpoint, max_wait_secs, config, init_feed_dict, init_fn)
#     277                            "init_fn or local_init_op was given")
#     278       if init_op is not None:
# --> 279         sess.run(init_op, feed_dict=init_feed_dict)
#     280       if init_fn:
#     281         init_fn(sess)
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1295                 run_metadata):
#    1296       # Ensure any changes to the graph are reflected in the runtime.
# -> 1297       self._extend_graph()
#    1298       with errors.raise_exception_on_not_ok_status() as status:
#    1299         if self._created_with_new_api:
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _extend_graph(self)
#    1356         with errors.raise_exception_on_not_ok_status() as status:
#    1357           tf_session.TF_ExtendGraph(
# -> 1358               self._session, graph_def.SerializeToString(), status)
#    1359         self._opened = True
#    1360
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/google/protobuf/internal/python_message.pyc in SerializeToString(self)
#    1062           'Message %s is missing required fields: %s' % (
#    1063           self.DESCRIPTOR.full_name, ','.join(self.FindInitializationErrors())))
# -> 1064     return self.SerializePartialToString()
#    1065   cls.SerializeToString = SerializeToString
#    1066
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/google/protobuf/internal/python_message.pyc in SerializePartialToString(self)
#    1071   def SerializePartialToString(self):
#    1072     out = BytesIO()
# -> 1073     self._InternalSerialize(out.write)
#    1074     return out.getvalue()
#    1075   cls.SerializePartialToString = SerializePartialToString
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/google/protobuf/internal/python_message.pyc in InternalSerialize(self, write_bytes)
#    1077   def InternalSerialize(self, write_bytes):
#    1078     for field_descriptor, field_value in self.ListFields():
# -> 1079       field_descriptor._encoder(write_bytes, field_value)
#    1080     for tag_bytes, value_bytes in self._unknown_fields:
#    1081       write_bytes(tag_bytes)
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/google/protobuf/internal/encoder.pyc in EncodeRepeatedField(write, value)
#     754       for element in value:
#     755         write(tag)
# --> 756         local_EncodeVarint(write, element.ByteSize())
#     757         element._InternalSerialize(write)
#     758     return EncodeRepeatedField
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/google/protobuf/internal/python_message.pyc in ByteSize(self)
#    1039     size = 0
#    1040     for field_descriptor, field_value in self.ListFields():
# -> 1041       size += field_descriptor._sizer(field_value)
#    1042
#    1043     for tag_bytes, value_bytes in self._unknown_fields:
#
# /data/home/guanggao/anaconda2/lib/python2.7/site-packages/google/protobuf/internal/encoder.pyc in RepeatedFieldSize(value)
#     239       result = tag_size * len(value)
#     240       for element in value:
# --> 241         l = local_len(element.encode('utf-8'))
#     242         result += local_VarintSize(l) + l
#     243       return result
#
# KeyboardInterrupt:

# %%
df_data = pd.read_csv("../data/train_df_new.csv",engine="python",index_col=0)

# %%
df_data
# Out:
#        parcelid  logerror  airconditioningtypeid  architecturalstyletypeid  \
# 0      11016594         0                      1                        -1
# 1      14366692         0                     -1                        -1
# 2      12098116         0                      1                        -1
# 3      12643413         0                      1                        -1
# 4      14432541         0                     -1                        -1
# 5      11509835         0                      1                        -1
# 6      12286022         0                     -1                        -1
# 7      17177301         0                     -1                        -1
# 8      14739064         0                     -1                        -1
# 9      14677559         0                     -1                        -1
# 10     10854446         0                     -1                        -1
# 11     11672170         0                      1                        -1
# 12     10949761         0                     -1                        -1
# 13     14665244         0                     -1                        -1
# 14     14148540         0                     -1                        -1
# 15     14057104         0                      5                        -1
# 16     17296797         0                     -1                        -1
# 17     12524288         0                     -1                        -1
# 18     14091502         0                     -1                        -1
# 19     10815909         0                      1                        -1
# 20     12453853         0                     -1                        -1
# 21     14253461         0                     13                        -1
# 22     14001034         0                     -1                        -1
# 23     11458863         0                     -1                        -1
# 24     13957980         0                     -1                        -1
# 25     12752047         0                      1                        -1
# 26     11188425         0                      1                        -1
# 27     14646051         0                     -1                        -1
# 28     10805063         0                      1                        -1
# 29     12524725         0                     -1                        -1
# 30     11104966         0                     -1                        -1
# 31     11624877         0                      1                        -1
# ...         ...       ...                    ...                       ...
# 90243  17182881         0                     -1                        -1
# 90244  11143993         0                      1                        -1
# 90245  10757551         0                     -1                        -1
# 90246  12558267         0                      1                        -1
# 90247  11710734         0                     -1                        -1
# 90248  14347592         0                     13                        -1
# 90249  11341061         0                     -1                        -1
# 90250  14027878         0                     -1                        -1
# 90251  12756771         0                     -1                        -1
# 90252  12758333         0                      1                        -1
# 90253  11295458         0                      1                        -1
# 90254  12757889         0                      1                        -1
# 90255  11308315         0                      1                        -1
# 90256  14353215         0                     -1                        -1
# 90257  10753416         0                      1                        -1
# 90258  11756902         0                      1                        -1
# 90259  11994047         0                      1                        -1
# 90260  11440746         0                     -1                        -1
# 90261  11703478         0                     -1                        -1
# 90262  10965821         0                      1                        -1
# 90263  12067066         0                      1                        -1
# 90264  11683263         0                      1                        -1
# 90265  12062080         0                      1                        -1
# 90266  12265636         0                     -1                        -1
# 90267  17109680         0                     -1                        -1
# 90268  12268527         0                      1                        -1
# 90269  12920746         0                     -1                        -1
# 90270  10774160         0                      1                        -1
# 90271  12046695         0                     -1                        -1
# 90272  12995401         0                     -1                        -1
# 90273  11402105         0                     -1                        -1
# 90274  12566293         0                     -1                        -1
#
#        basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0                -1            2           3                   -1
# 1                -1            3           4                   -1
# 2                -1            3           2                   -1
# 3                -1            2           2                   -1
# 4                -1            2           4                   -1
# 5                -1            4           4                   -1
# 6                -1            1           2                   -1
# 7                -1            2           3                   -1
# 8                -1            1           2                   -1
# 9                -1            2           2                   -1
# 10               -1            2           2                   -1
# 11               -1            4           5                   -1
# 12               -1            2           3                   -1
# 13               -1            2           2                   -1
# 14               -1            2           2                   -1
# 15               -1            2           3                   -1
# 16               -1            2           3                   -1
# 17               -1            1           1                   -1
# 18               -1            2           3                   -1
# 19               -1            3           3                   -1
# 20               -1            1           2                   -1
# 21               -1            2           2                   -1
# 22               -1            2           4                   -1
# 23               -1            4           3                   -1
# 24               -1            2           2                   -1
# 25               -1            4           3                   -1
# 26               -1            2           2                   -1
# 27               -1            2           2                   -1
# 28               -1            2           2                   -1
# 29               -1            3           2                   -1
# 30               -1            2           4                   -1
# 31               -1            2           2                   -1
# ...             ...          ...         ...                  ...
# 90243            -1            2           3                   -1
# 90244            -1            3           3                   -1
# 90245            -1            3           3                   -1
# 90246            -1            2           2                   -1
# 90247            -1            2           2                   -1
# 90248            -1            2           4                   -1
# 90249            -1            1           1                   -1
# 90250            -1            2           3                   -1
# 90251            -1            1           3                   -1
# 90252            -1            3           3                   -1
# 90253            -1            2           2                   -1
# 90254            -1            2           3                   -1
# 90255            -1            3           5                   -1
# 90256            -1            2           3                   -1
# 90257            -1            2           2                   -1
# 90258            -1            3           3                   -1
# 90259            -1            2           1                   -1
# 90260            -1            2           2                   -1
# 90261            -1            1           3                   -1
# 90262            -1            2           3                   -1
# 90263            -1            2           2                   -1
# 90264            -1            3           3                   -1
# 90265            -1            1           2                   -1
# 90266            -1            2           4                   -1
# 90267            -1            2           4                   -1
# 90268            -1            3           3                   -1
# 90269            -1            2           3                   -1
# 90270            -1            1           1                   -1
# 90271            -1            3           3                   -1
# 90272            -1            2           4                   -1
# 90273            -1            2           2                   -1
# 90274            -1            1           3                   -1
#
#        buildingqualitytypeid  calculatedbathnbr        ...         \
# 0                          4                  2        ...
# 1                         -1                  3        ...
# 2                          4                  3        ...
# 3                          4                  2        ...
# 4                         -1                  2        ...
# 5                          1                  4        ...
# 6                          7                  1        ...
# 7                         -1                  2        ...
# 8                         -1                  1        ...
# 9                         -1                  2        ...
# 10                         7                  2        ...
# 11                         1                  4        ...
# 12                         7                  2        ...
# 13                        -1                  2        ...
# 14                        -1                  2        ...
# 15                        -1                  2        ...
# 16                        -1                  2        ...
# 17                         7                  1        ...
# 18                        -1                  2        ...
# 19                         4                  3        ...
# 20                         7                  1        ...
# 21                        -1                  2        ...
# 22                        -1                  2        ...
# 23                         4                  4        ...
# 24                        -1                  2        ...
# 25                         7                  4        ...
# 26                         4                  2        ...
# 27                        -1                  2        ...
# 28                         4                  2        ...
# 29                         4                  3        ...
# 30                         7                  2        ...
# 31                         1                  2        ...
# ...                      ...                ...        ...
# 90243                     -1                  2        ...
# 90244                      4                  3        ...
# 90245                      4                  3        ...
# 90246                     -1                  2        ...
# 90247                      4                  2        ...
# 90248                     -1                  2        ...
# 90249                      7                  1        ...
# 90250                     -1                  2        ...
# 90251                      7                  1        ...
# 90252                      7                  3        ...
# 90253                      7                  2        ...
# 90254                      7                  2        ...
# 90255                      4                  3        ...
# 90256                     -1                  2        ...
# 90257                      4                  2        ...
# 90258                      1                  3        ...
# 90259                      1                  2        ...
# 90260                      4                  2        ...
# 90261                      7                  1        ...
# 90262                      7                  2        ...
# 90263                      7                  2        ...
# 90264                     10                  3        ...
# 90265                      4                  1        ...
# 90266                      7                  2        ...
# 90267                     -1                  2        ...
# 90268                      4                  3        ...
# 90269                      4                  2        ...
# 90270                      4                  1        ...
# 90271                      4                  3        ...
# 90272                      7                  2        ...
# 90273                      4                  2        ...
# 90274                      7                  1        ...
#
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                        122754.0           360170.0            2015
# 1                        346458.0           585529.0            2015
# 2                         61994.0           119906.0            2015
# 3                        171518.0           244880.0            2015
# 4                        169574.0           434551.0            2015
# 5                        880650.0          2447951.0            2015
# 6                         64549.0           111521.0            2015
# 7                        107000.0           306000.0            2015
# 8                         66834.0           210064.0            2015
# 9                        109977.0           190960.0            2015
# 10                        55396.0           105954.0            2015
# 11                       559040.0          1090127.0            2015
# 12                        29551.0            70119.0            2015
# 13                       398747.0           601000.0            2015
# 14                        78565.0           254817.0            2015
# 15                        89850.0           345023.0            2015
# 16                       168000.0           480000.0            2015
# 17                        56233.0            70316.0            2015
# 18                        75119.0           253138.0            2015
# 19                       108985.0           416279.0            2015
# 20                       122952.0           260249.0            2015
# 21                       109293.0           258960.0            2015
# 22                        92991.0           212077.0            2015
# 23                       319449.0          1194279.0            2015
# 24                       157171.0           335790.0            2015
# 25                       154186.0           239456.0            2015
# 26                        80600.0           174000.0            2015
# 27                       145291.0           825000.0            2015
# 28                       135218.0           250245.0            2015
# 29                       117504.0           215097.0            2015
# 30                       176891.0           335093.0            2015
# 31                       202000.0           673000.0            2015
# ...                           ...                ...             ...
# 90243                     90938.0           113965.0            2015
# 90244                    294677.0           399596.0            2015
# 90245                    200424.0           324821.0            2015
# 90246                    315000.0           464000.0            2015
# 90247                     35465.0            69303.0            2015
# 90248                    233044.0           615410.0            2015
# 90249                     13234.0            20756.0            2015
# 90250                     99182.0           257206.0            2015
# 90251                     65728.0           307167.0            2015
# 90252                    134709.0           203256.0            2015
# 90253                     40163.0            50203.0            2015
# 90254                    147672.0           344882.0            2015
# 90255                    248378.0           331525.0            2015
# 90256                    194714.0           713656.0            2015
# 90257                    221809.0           295743.0            2015
# 90258                    259644.0           504864.0            2015
# 90259                    140145.0           448790.0            2015
# 90260                     58100.0           220600.0            2015
# 90261                     17520.0            39934.0            2015
# 90262                    140984.0           297456.0            2015
# 90263                    117807.0           361072.0            2015
# 90264                    532796.0          1331992.0            2015
# 90265                    106689.0           266825.0            2015
# 90266                     19554.0            32581.0            2015
# 90267                    180034.0           300054.0            2015
# 90268                    192373.0           315288.0            2015
# 90269                    141700.0           405000.0            2015
# 90270                     43800.0           191000.0            2015
# 90271                    117893.0           161111.0            2015
# 90272                     22008.0            38096.0            2015
# 90273                    132991.0           165869.0            2015
# 90274                     66258.0           163037.0            2015
#
#        landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 0                   237416.0    6735.88             missing
# 1                   239071.0   10153.02             missing
# 2                    57912.0   11484.48             missing
# 3                    73362.0    3048.74             missing
# 4                   264977.0    5488.96             missing
# 5                  1567301.0   27126.57             missing
# 6                    46972.0    2304.97             missing
# 7                   199000.0    3745.50             missing
# 8                   143230.0    2172.88             missing
# 9                    80983.0    1940.26             missing
# 10                   50558.0    1443.69             missing
# 11                  531087.0   13428.94             missing
# 12                   40568.0     832.35             missing
# 13                  202253.0    6876.70             missing
# 14                  176252.0    3192.28             missing
# 15                  255173.0    4036.32             missing
# 16                  312000.0    6383.74             missing
# 17                   14083.0     913.17             missing
# 18                  178019.0    3329.14             missing
# 19                  307294.0    5194.00             missing
# 20                  137297.0    3211.31             missing
# 21                  149667.0    3090.72             missing
# 22                  119086.0    3020.24             missing
# 23                  874830.0   14747.98             missing
# 24                  178619.0    4269.90             missing
# 25                   85270.0    3249.37             missing
# 26                   93400.0    3895.76             missing
# 27                  679709.0    9553.56             missing
# 28                  115027.0    3117.19             missing
# 29                   97593.0    2648.96             missing
# 30                  158202.0    4499.03             missing
# 31                  471000.0    8048.18             missing
# ...                      ...        ...                 ...
# 90243                23027.0    1394.72             missing
# 90244               104919.0    5692.71             missing
# 90245               124397.0    6427.03             missing
# 90246               149000.0    6286.13             missing
# 90247                33838.0     964.14             missing
# 90248               382366.0    6379.72             missing
# 90249                 7522.0    1295.30             missing
# 90250               158024.0    3148.18             missing
# 90251               241439.0    4038.70             missing
# 90252                68547.0    2761.24             missing
# 90253                10040.0    1263.39                   Y
# 90254               197210.0    4493.66             missing
# 90255                83147.0    6461.79             missing
# 90256               518942.0    7380.64             missing
# 90257                73934.0    4330.78             missing
# 90258               245220.0    6286.52             missing
# 90259               308645.0    5459.11             missing
# 90260               162500.0    3596.07             missing
# 90261                22414.0     627.91             missing
# 90262               156472.0    3738.38             missing
# 90263               243265.0    4044.68             missing
# 90264               799196.0   18297.87             missing
# 90265               160136.0    3075.18             missing
# 90266                13027.0    6137.29             missing
# 90267               120020.0    3172.68             missing
# 90268               122915.0    5853.81             missing
# 90269               263300.0    5311.03             missing
# 90270               147200.0    2495.24             missing
# 90271                43218.0    1886.54             missing
# 90272                16088.0    1925.70                   Y
# 90273                32878.0    2285.57             missing
# 90274                96779.0    2560.96             missing
#
#        taxdelinquencyyear  censustractandblock  transaction_month  \
# 0                      -1         6.037107e+13                  1
# 1                      -1        -1.000000e+00                  1
# 2                      -1         6.037464e+13                  1
# 3                      -1         6.037296e+13                  1
# 4                      -1         6.059042e+13                  1
# 5                      -1         6.037621e+13                  1
# 6                      -1         6.037542e+13                  1
# 7                      -1         6.111003e+13                  1
# 8                      -1         6.059042e+13                  1
# 9                      -1         6.059063e+13                  1
# 10                     -1         6.037141e+13                  1
# 11                     -1         6.037263e+13                  1
# 12                     -1         6.037311e+13                  1
# 13                     -1         6.059063e+13                  1
# 14                     -1         6.059002e+13                  1
# 15                     -1         6.059099e+13                  1
# 16                     -1         6.111007e+13                  1
# 17                     -1         6.037575e+13                  1
# 18                     -1         6.059100e+13                  1
# 19                     -1         6.037140e+13                  1
# 20                     -1         6.037570e+13                  1
# 21                     -1         6.059075e+13                  1
# 22                     -1         6.059110e+13                  1
# 23                     -1         6.037277e+13                  1
# 24                     -1         6.059089e+13                  1
# 25                     -1         6.037504e+13                  1
# 26                     -1         6.037910e+13                  1
# 27                     -1         6.059042e+13                  1
# 28                     -1         6.037140e+13                  1
# 29                     -1         6.037577e+13                  1
# 30                     -1         6.037920e+13                  1
# 31                     -1         6.037269e+13                  1
# ...                   ...                  ...                ...
# 90243                  -1         6.111005e+13                 12
# 90244                  -1         6.037920e+13                 12
# 90245                  -1         6.037137e+13                 12
# 90246                  -1         6.037576e+13                 12
# 90247                  -1         6.037234e+13                 12
# 90248                  -1         6.059052e+13                 12
# 90249                  -1         6.037920e+13                 12
# 90250                  -1         6.059100e+13                 12
# 90251                  -1         6.037553e+13                 12
# 90252                  -1         6.037553e+13                 12
# 90253                  15         6.037901e+13                 12
# 90254                  -1         6.037553e+13                 12
# 90255                  -1         6.037901e+13                 12
# 90256                  -1         6.059052e+13                 12
# 90257                  -1         6.037800e+13                 12
# 90258                  -1         6.037213e+13                 12
# 90259                  -1         6.037192e+13                 12
# 90260                  -1         6.037604e+13                 12
# 90261                  -1         6.037232e+13                 12
# 90262                  -1         6.037107e+13                 12
# 90263                  -1         6.037302e+13                 12
# 90264                  -1         6.037801e+13                 12
# 90265                  -1         6.037302e+13                 12
# 90266                  -1         6.037543e+13                 12
# 90267                  -1         6.111002e+13                 12
# 90268                  -1         6.037541e+13                 12
# 90269                  -1         6.037404e+13                 12
# 90270                  -1         6.037132e+13                 12
# 90271                  -1         6.037301e+13                 12
# 90272                  14         6.037433e+13                 12
# 90273                  -1         6.037601e+13                 12
# 90274                  -1         6.037544e+13                 12
#
#        transaction_year
# 0                  2016
# 1                  2016
# 2                  2016
# 3                  2016
# 4                  2016
# 5                  2016
# 6                  2016
# 7                  2016
# 8                  2016
# 9                  2016
# 10                 2016
# 11                 2016
# 12                 2016
# 13                 2016
# 14                 2016
# 15                 2016
# 16                 2016
# 17                 2016
# 18                 2016
# 19                 2016
# 20                 2016
# 21                 2016
# 22                 2016
# 23                 2016
# 24                 2016
# 25                 2016
# 26                 2016
# 27                 2016
# 28                 2016
# 29                 2016
# 30                 2016
# 31                 2016
# ...                 ...
# 90243              2016
# 90244              2016
# 90245              2016
# 90246              2016
# 90247              2016
# 90248              2016
# 90249              2016
# 90250              2016
# 90251              2016
# 90252              2016
# 90253              2016
# 90254              2016
# 90255              2016
# 90256              2016
# 90257              2016
# 90258              2016
# 90259              2016
# 90260              2016
# 90261              2016
# 90262              2016
# 90263              2016
# 90264              2016
# 90265              2016
# 90266              2016
# 90267              2016
# 90268              2016
# 90269              2016
# 90270              2016
# 90271              2016
# 90272              2016
# 90273              2016
# 90274              2016
#
# [90275 rows x 61 columns]
